# %%
from collections import namedtuple

Set = namedtuple("Set", ['index', 'cost', 'items'])
#file_location = 'data/sc_45_0'
#file_location = 'data/sc_1092610_0'
file_location = 'data/sc_63009_0'
with open(file_location, 'r') as input_data_file:
    input_data = input_data_file.read()

# %%
lines = input_data.split('\n')

parts = lines[0].split()
item_count = int(parts[0])
set_count = int(parts[1])

sets = []
for i in range(1, set_count+1):
    parts = lines[i].split()
    sets.append(Set(i-1, float(parts[0]), set(map(int, parts[1:]))))

# %%
from greedy_solver import best_valued_set, greedy_solver
from bb_solver import bb_solver, get_cost, _bb_solve, _back_track, _is_valid

# %%
solution_g = greedy_solver(sets, item_count)
get_cost(sets, solution_g)
# Out:
# 216.0

# %%
# %reload_ext line_profiler
# %lprun -f _back_track bb_solver(sets, item_count, max_time = 120)
# Out:
# greedy costs:  33.0
# *** KeyboardInterrupt exception caught in code being profiled.

# %%
solution_b, optimal, num_iterations, progress = bb_solver(sets, item_count, max_time = 120)
# Out:
# greedy costs:  216.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-f5d509d14293> in <module>
# ----> 1 solution_b, optimal, num_iterations, progress = bb_solver(sets, item_count, max_time = 120)
#
# ~/git/setcover/bb_solver.py in bb_solver(sets, item_count, max_time)
#     119         sorted_best_taken[i] = best_taken[s.index]
#     120
# --> 121     sorted_taken, optimal, num_iterations, progress = _bb_solve(sorted_sets, item_count, sorted_best_taken, best_cost, max_time)
#     122     taken = [0]*len(sets)
#     123     for i,t in enumerate(sorted_taken):
#
# ~/git/setcover/bb_solver.py in _bb_solve(sets, item_count, best_taken, best_cost, max_time)
#      94                 break
#      95             else:
# ---> 96                 current_cost = get_cost(sets, current_taken)
#      97         else:
#      98             s = sets[len(current_taken)]
#
# ~/git/setcover/bb_solver.py in get_cost(sets, current_taken)
#      40
#      41 def get_cost(sets, current_taken):
# ---> 42     return sum([s.cost*current_taken[s.index] for s in sets])
#      43     #return sum([sets[i].cost*t for i, t in enumerate(current_taken)])
#      44
#
# ~/git/setcover/bb_solver.py in <listcomp>(.0)
#      40
#      41 def get_cost(sets, current_taken):
# ---> 42     return sum([s.cost*current_taken[s.index] for s in sets])
#      43     #return sum([sets[i].cost*t for i, t in enumerate(current_taken)])
#      44
#
# IndexError: list index out of range

# %%
get_cost(sets, solution_b)

# %%
optimal
# Out:
# 0

# %%
num_iterations
# Out:
# 2395

# %%
progress
# Out:
# ...

# %%
from mip_solver import mip_solver

# %%
solution_mip, optimal = mip_solver(sets, item_count, solution_g, max_time = 120)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-852750fee419> in <module>
# ----> 1 solution_mip, optimal = mip_solver(sets, item_count, solution_g, max_time = 120)
#
# ~/git/setcover/mip_solver.py in mip_solver(sets, item_count, start_solution, max_time)
#      18     x = [solver.IntVar(0, 1, 'x'+str(s.index)) for s in sets]
#      19     for j in range(item_count):
# ---> 20         solver.Add(solver.Sum([x[s.index]*cover[s.index][j] for s in sets]) >= 1)
#      21
#      22     solver.Minimize(solver.Sum([x[s.index]*s.cost for s in sets]))
#
# ~/anaconda3/lib/python3.8/site-packages/ortools/linear_solver/pywraplp.py in Add(self, constraint, name)
#     490           return self.RowConstraint(1, 1, name)
#     491       else:
# --> 492         return constraint.Extract(self, name)
#     493
#     494     def Sum(self, expr_array):
#
# ~/anaconda3/lib/python3.8/site-packages/ortools/linear_solver/linear_solver_natural_api.py in Extract(self, solver, name)
#     251   def Extract(self, solver, name=''):
#     252     """Performs the actual creation of the constraint object."""
# --> 253     coeffs = self.__expr.GetCoeffs()
#     254     constant = coeffs.pop(OFFSET_KEY, 0.0)
#     255     lb = -solver.infinity()
#
# ~/anaconda3/lib/python3.8/site-packages/ortools/linear_solver/linear_solver_natural_api.py in GetCoeffs(self)
#      98     while stack:
#      99       current_multiplier, current_expression = stack.pop()
# --> 100       current_expression.AddSelfToCoeffMapOrStack(coeffs, current_multiplier,
#     101                                                   stack)
#     102     return coeffs
#
# ~/anaconda3/lib/python3.8/site-packages/ortools/linear_solver/linear_solver_natural_api.py in AddSelfToCoeffMapOrStack(self, coeffs, multiplier, stack)
#     218     # predictable from user perspective.
#     219     for arg in reversed(self.__array):
# --> 220       stack.append((multiplier, arg))
#     221
#     222
#
# KeyboardInterrupt:

# %%
optimal

# %%
get_cost(sets, solution_mip)
